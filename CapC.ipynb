# %% [markdown]
# <a href="https://colab.research.google.com/github/Lebakmanideep/Data-science/blob/main/CapC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('caps.csv')
df.head()
# Out:
#     sex  age  height  weight  waistline  sight_left  sight_right  hear_left  \
# 0  Male   35     170      75       90.0         1.0          1.0        1.0
# 1  Male   30     180      80       89.0         0.9          1.2        1.0
# 2  Male   40     165      75       91.0         1.2          1.5        1.0
# 3  Male   50     175      80       91.0         1.5          1.2        1.0
# 4  Male   50     165      60       80.0         1.0          1.2        1.0
#
#    hear_right    SBP  ...  LDL_chole  triglyceride  hemoglobin  urine_protein  \
# 0         1.0  120.0  ...      126.0          92.0        17.1            1.0
# 1         1.0  130.0  ...      148.0         121.0        15.8            1.0
# 2         1.0  120.0  ...       74.0         104.0        15.8            1.0
# 3         1.0  145.0  ...      104.0         106.0        17.6            1.0
# 4         1.0  138.0  ...      117.0         104.0        13.8            1.0
#
# ...

# %%
df.describe().T
# Out:
#                     count        mean         std    min     25%    50%  \
# age               56924.0   47.605667   14.160254   20.0   35.00   45.0
# height            56924.0  162.240707    9.297570  130.0  155.00  160.0
# weight            56924.0   63.241691   12.514918   30.0   55.00   60.0
# waistline         56924.0   81.218967   11.697016   35.0   74.00   81.0
# sight_left        56924.0    0.981690    0.616199    0.1    0.70    1.0
# sight_right       56924.0    0.980160    0.615569    0.1    0.70    1.0
# hear_left         56924.0    1.030550    0.172095    1.0    1.00    1.0
# hear_right        56924.0    1.029355    0.168801    1.0    1.00    1.0
# SBP               56924.0  122.398233   14.508441   75.0  112.00  120.0
# DBP               56924.0   76.029179    9.920796   42.0   70.00   76.0
# BLDS              56924.0  100.515740   24.399199   47.0   88.00   96.0
# tot_chole         56924.0  195.665255   38.325863   54.0  169.75  194.0
# ...

# %%
#Preprocessing and Data Cleansing

df.iloc[0,:]
# Out:
# sex                  Male
# age                    35
# height                170
# weight                 75
# waistline            90.0
# sight_left            1.0
# sight_right           1.0
# hear_left             1.0
# hear_right            1.0
# SBP                 120.0
# DBP                  80.0
# BLDS                 99.0
# tot_chole           193.0
# HDL_chole            48.0
# LDL_chole           126.0
# triglyceride         92.0
# hemoglobin           17.1
# urine_protein         1.0
# serum_creatinine      1.0
# SGOT_AST             21.0
# SGOT_ALT             35.0
# gamma_GTP            40.0
# SMK_stat_type_cd      1.0
# DRK_YN                  Y
# female                  0
# Name: 0, dtype: object

# %% [markdown]
# For the binary categorical variables:
#
# Sex (F/M) will be encoded as 1 for Female (F) and 0 for Male (M).
# Drinker (yes/no) will be encoded as 1 for Yes (drinker) and 0 for No (non-drinker).
# For the target variable:
#
# SMK_stat_type_cd, which represents the smoking state, will be encoded as follows:
# 0 for "never smoked" (SMK_stat_type_cd = 1)
# 1 for "has smoked or is currently a smoker" (SMK_stat_type_cd = 2 or 3)
# This encoding simplifies the information, making it easier to work with these variables in a binary format.

# %%
df["female"] = pd.get_dummies(df['sex'],1).iloc[:,0]

for i in range(df.shape[0]):
    if df['female'][i] == False:
        df['female'][i] = 0
    else:
        df['female'][i] = 1

df.iloc[:,[0,-1]]
# Out:
# <ipython-input-7-c0d93ea64899>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['female'][i] = 0
# <ipython-input-7-c0d93ea64899>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['female'][i] = 1
#           sex  female
# 0        Male       0
# 1        Male       0
# 2        Male       0
# 3        Male       0
# 4        Male       0
# ...       ...     ...
# 56919  Female       1
# 56920  Female       1
# 56921    Male       0
# 56922  Female       1
# 56923  Female       1
#
# [56924 rows x 2 columns]

# %%
df["drinker"] = pd.get_dummies(df['DRK_YN'],0).iloc[:,1]
for i in range(df.shape[0]):
    if df['drinker'][i] == False:
        df['drinker'][i] = 0
    else:
        df['drinker'][i] = 1


df.iloc[:,[-3,-1]]
# Out:
# <ipython-input-8-697cdbffd492>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['drinker'][i] = 1
# <ipython-input-8-697cdbffd492>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['drinker'][i] = 0
#       DRK_YN  drinker
# 0          Y        1
# 1          N        0
# 2          N        0
# 3          N        0
# 4          N        0
# ...      ...      ...
# 56919      Y        1
# 56920      N        0
# 56921      N        0
# 56922      Y        1
# 56923    NaN        0
#
# [56924 rows x 2 columns]

# %%
df['smokers'] = df['SMK_stat_type_cd'] - 1 #sets ones to zero, twos to ones, and threes to twos
df['smokers'].loc[df['smokers'] > 1  ] = 1 #changes twos to ones
df['smokers'].describe() #mean shows us how many smokers in dataset
# Out:
# <ipython-input-9-04d2c60f90a1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['smokers'].loc[df['smokers'] > 1  ] = 1 #changes twos to ones
# count    56923.000000
# mean         0.394761
# std          0.488804
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: smokers, dtype: float64

# %%
nan_counts = [(column, df[column].isna().sum()) for column in df.columns]
nan_counts
# Out:
# [('sex', 0),
#  ('age', 0),
#  ('height', 0),
#  ('weight', 0),
#  ('waistline', 0),
#  ('sight_left', 0),
#  ('sight_right', 0),
#  ('hear_left', 0),
#  ('hear_right', 0),
#  ('SBP', 0),
#  ('DBP', 0),
#  ('BLDS', 0),
#  ('tot_chole', 0),
#  ('HDL_chole', 1),
#  ('LDL_chole', 1),
#  ('triglyceride', 1),
#  ('hemoglobin', 1),
#  ('urine_protein', 1),
#  ('serum_creatinine', 1),
#  ('SGOT_AST', 1),
#  ('SGOT_ALT', 1),
#  ('gamma_GTP', 1),
#  ('SMK_stat_type_cd', 1),
#  ('DRK_YN', 1),
#  ('female', 0),
#  ('drinker', 0),
#  ('smokers', 1)]

# %%
df.drop('SMK_stat_type_cd', axis=1, inplace=True)
df.drop("DRK_YN", axis=1, inplace=True)
df.drop("sex", axis=1, inplace =True)
df.columns
# Out:
# Index(['age', 'height', 'weight', 'waistline', 'sight_left', 'sight_right',
#        'hear_left', 'hear_right', 'SBP', 'DBP', 'BLDS', 'tot_chole',
#        'HDL_chole', 'LDL_chole', 'triglyceride', 'hemoglobin', 'urine_protein',
#        'serum_creatinine', 'SGOT_AST', 'SGOT_ALT', 'gamma_GTP', 'female',
#        'drinker', 'smokers'],
#       dtype='object')

# %% [markdown]
# "In our dataset, 39.2% of respondents fall into the category of individuals who are or were smokers, while the remaining majority, 60.8%, have never initiated smoking."

# %% [markdown]
# **Visualize Correlations**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(16, 6))

# Calculate the correlation matrix using Pearson method
correlation_matrix = df.corr(method='pearson')

# Create the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='rainbow')

plt.title('Pairwise Correlation Heatmap', fontsize=12, pad=12)

# Show the plot
plt.show()

# %% [markdown]
# *  there are some highly correlated columns depending up a person's sex.
# height is highly correlated to weight.
# *  waistline is highly correlated to weight.
# *  Systolic Blood Pressures is highly correlated to Diastolic Blood Pressure.
# *  LDL Cholestoral is highly correlated to total cholestoral.
# *  SGOT_AST(Glutamate-oxaloacetate transaminase)(Aspartate transaminase) correlates highly with (Alanine transaminase).
